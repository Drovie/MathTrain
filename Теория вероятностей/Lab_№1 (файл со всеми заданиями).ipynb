# %%
#Задача №1

#В урне 4 белых и 6 черных шаров. Из урны наудачу извлечены 2 шара. Найти 
#вероятность того, что они разного цвета.



import math
#Всего шаров - 10
#Выборка - 2
#Белых шаров - 4
#Чёрных шаров - 6

k = int(input("Введит количество выбираемых шаров: ")) #количество выбираемых шаров
n = int(input("Введите общее количество шаров: ")) #общее количество шаров

k1 = int (input('Введите количество белых шаров: ' )) #количество белых шаров
k2 = int (input('Введите количество чёрных шаров: ' )) #количество чёрных шаров


A1 = math.comb(n, k)
print("Количество способов выбрать 2 шара из 10: ", A1)

A2_1 = math.comb(k1, 1)
print("Количество способов выбрать 1 белый шар: ", A2_1)

A2_2 = math.comb(k2, 1)
print("Количество способов выбрать 1 чёрный шар: ", A2_2)

A3 = A2_1 * A2_2
print("Количество способов выбрать 1 чёрный и 1 белый шар: ", A3)

print ("Вероятность выбора 2 разных шаров из 10: ", A3/A1 )
# Out:
# Количество способов выбрать 2 шара из 10:  45
# Количество способов выбрать 1 белый шар:  4
# Количество способов выбрать 1 чёрный шар:  6
# Количество способов выбрать 1 чёрный и 1 белый шар:  24
# Вероятность выбора 2 разных шаров из 10:  0.5333333333333333

# %%
#Задача №2

#Какова вероятность того, что пятизначное число 
#состоит из цифр 0, 1, 2, 3, 4.

#Всего 10 цифр. На первом месте не может быть 0, 
#тогда для составления пятизначного числа на первый разряд 
#может встать 9 цифр, а на последующие - по 10, значит:

m = 9*10*10*10*10 #Количество пятизначных цифр

#Теперь доступно всего 5 цифр - 0,1,2,3,4. Не первом месте не может стоять 0
#Тогда для составления пятизначного числа на первый разряд 
#может встать 4 цифы, а на последующие - по 5, значит:

n = 4*5*5*5*5

#Вероятность, что пятизначное число будет содержать в себе цифры 0,1,2,3,4:
P_A = n/m
print("Вероятность, что пятизначное число состоит из цифр 0,1,2,3,4: ",P_A)
# Out:
# Вероятность, что пятизначное число состоит из цифр 0,1,2,3,4:  0.027777777777777776

# %%
#Задача 3

#Студент  сдает  три  экзамена.  Вероятность  успешной  сдачи  первого  экзамена 
#0,9,  второго  –  0,65,  третьего  –  0,35.  Найти  вероятность  того,  что  он  не  сдаст  хотя  бы  один экзамен.

#Вероятности успеха
P_A1 = 0.9
P_A2 = 0.65
P_A3 = 0.35
#Вероятности провала
Q_A1 = 1-P_A1
Q_A2 = 1-P_A2
Q_A3 = 1-P_A3

#Событие "Не сдать хотя бы один экзамен - 
#это событие, обратное для "сдать все экзамены"

P_A = P_A1*P_A2*P_A3
print ("Вероятность сдачи всех трёх экзаменов: ", P_A)

print ("Вероятность не сдачи хотя бы одного экзамена: ",1-P_A)
# Out:
# Вероятность сдачи всех трёх экзаменов:  0.20475000000000002
# Вероятность не сдачи хотя бы одного экзамена:  0.79525

# %%
#Задача 4

#Пароль для входа в компьютерную базу данных состоит из 7 цифр. 
##Какова вероятность правильного набора пароля с первого раза, 
###если комбинация цифр является строго возрастающей последовательностью. 


import math
#Количество символов в пароле по условию - 7
k = int(input("Введит количество символов в пароле: ")) #количество цифр, из которых состоит пароль

A1 = math.comb(10, k)
print("Количество способов выбрать ", k, " цифр из 10 существующих: ", A1)

#Количество благоприятных исходов равно 1, тогда:

print("Вероятность правильного подбора пароля: ", 1/A1)
# Out:
# Количество способов выбрать  7  цифр из 10 существующих:  120
# Вероятность правильного подбора пароля:  0.008333333333333333

# %%
#Задача 5

#Бросают игральный кубик. Какова вероятность того, что выпало четное число
#очков, если известно, что число выпавших очков меньше пяти?

#Если выпало меньше 5 очков, значит существует 4 возможных исхода - 1,2,3,4.
#Всего 2 исхода, при которых выпавшие числа чётные (2 и 4) тогда вероятность равна
P_A = 2/4
print("Вероятность, что выпавшее число очков - чётное и < 5: ", P_A)
# Out:
# Вероятность, что выпавшее число очков - чётное и < 5:  0.5

# %%
#Задание 6

#В лифт 20-этажного дома на первом этаже зашли 3 человека. 
#И поехали. Найти вероятность того, что: 
#а) они выйдут на разных этажах; 
#б) двое выйдут на одном этаже;
#в) все выйдут на одном этаже.

import math

n = 19 #количество этажей
#Каждый пассажир может выйти из лифта 19-ю способами, значит:
C1 = math.comb(n, 1)
print("Количество исходов для первого пассажира: ", C1)
C2 = math.comb(n, 1)
print("Количество исходов для второго пассажира: ", C2)
C3 = math.comb(n, 1)
print("Количество исходов для третьего пассажира: ", C3)

#Общее количество возможных исходов:
C = C1*C2*C3


#a)Каждый их пассажиров вышел на разных этажах
#Тогда у первого будет 19 возможных исходов, а у последующих на 1 меньше, предыдущего (18 и 17):
c1 = C1 * (C2-1) * (C3-2)

#Тогда вероятность выхода всех на разных этажах равна:
P_A1 = c1/C
print("Вероятность, что все выйдут на разных этажах: ",P_A1)


#в)
P_A3 = 19/C
print("Вероятность, что все выйдут на одном этаже: ",P_A3)

#б)

P_A2= 1-P_A1 - P_A3
print("Вероятность, что 2 на одном этаже: ",P_A2)
# Out:
# Количество исходов для первого пассажира:  19
# Количество исходов для второго пассажира:  19
# Количество исходов для третьего пассажира:  19
# Вероятность, что все выйдут на разных этажах:  0.8476454293628809
# Вероятность, что все выйдут на одном этаже:  0.002770083102493075
# Вероятность, что 2 на одном этаже:  0.14958448753462603

# %%
#Задание 7

#7. Из 36 карт наугад выбираются 3. Вычислите вероятность того, что среди них будут король и дама.

import math

P = "m(кол-во благоприятных сиходов)/n(общее кол-во исходов)"

"количество способов выбрать даму"
C1= math.comb(4, 1)

"количество способов выбрать короля"
C2= math.comb(4, 1)

"количество способов выбрать любую карту"
C3= math.comb(34, 1)

"Количество благоприятных исходов"
m = C1*C2*C3

"Общее количество исходов при выборе 3 карт из 36"
n = math.comb(36, 3)


"Вероятность, что в выборке будет король и дама"
P_A = m/n
print("Вероятность, что в выборке 3 карт из 36 будет король и дама: ",P_A)
# Out:
# Вероятность, что в выборке 3 карт из 36 будет король и дама:  0.0761904761904762

# %%
#Задание 8

#Для трех розничных торговых предприятий определен плановый уровень
#прибыли. Вероятность того, что первое предприятие выполнит план прибыли, равна 90%, 
#для второго она составляет 95%, для третьего 100%. 
#Какова вероятность того, что плановый уровень прибыли будет достигнут: 
#а) всеми предприятиями; б) только двумя предприятиями; в) хотя бы одним предприятием.


#А)Вероятность, что план будет достигнут всеми предприятиями
P_A = 0.9*0.95*1
print("Вероятность, что план будет достигнут всеми предприятиями: ",P_A)

#Б)Вероятность, что план будет достигнут только двумя предприятиями
P_B = 0.9*(1-0.95) + (1-0.9)*0.95
print("Вероятность, что план будет достигнут только двумя предприятиями: ",P_B)

#В)Вероятность, что план будет достигнут хотя бы одним предприятием
P_C = 1# так как третье предприятие выполняет план в 100% случаев
print("Вероятность, что план будет достигнут хотя бы одним предприятием: ",P_C)
# Out:
# Вероятность, что план будет достигнут всеми предприятиями:  0.855
# Вероятность, что план будет достигнут только двумя предприятиями:  0.14
# Вероятность, что план будет достигнут хотя бы одним предприятием:  1

# %%
#Задание 8

#Экзаменационный  билет  содержит  3  вопроса.  Вероятности  того,  что  студент 
#ответит на первый и второй вопросы одинаковы и равны 0,9; на третий – 0,8. 
#Найти вероятность того, что студент ответит: а) на все вопросы; б) по крайней мере, на два вопроса.

#a)Вероятность ответа на все вопросы
P_A = 0.9 * 0.9 * 0.8
print("Вероятность, что студент ответит на все вопросы: ",P_A)

#б)Вероятность, что ответит по крайней мере на 2
#Вероятность, что студент сдаст по крайней мере 3 экзамена - есть сумма вероятностей, что он сдаст 2 и сдаст 3 экзамена
#Вероятность, что студент сдаст ровно 2 экзамена
P_B = (0.9 * 0.9 * (1-0.8)) + (0.9 * (1-0.9) * 0.8) + ((1-0.9) * 0.9 * 0.8)
P_C = P_B + P_A
print("Вероятность, что студент ответит по крайней мере на 2 вопроса: ",P_C)
# Out:
# Вероятность, что студент ответит на все вопросы:  0.6480000000000001
# Вероятность, что студент ответит по крайней мере на 2 вопроса:  0.9540000000000002

# %%
#Задание 10

#.  Была  проведена  одна  и  та  же  контрольная  работа  в  трех  группах.  В  первой 
#группе  из  30  студентов  8  выполнили  работу  на  «отлично»,  во  второй,  
#где  28  студентов,  –  6 «отличных»  работ,  в  третьей,  где  27  студентов,  –  
#9  работ  выполнены  на  «отлично».  Найти вероятность  того, 
#что  первая  выбранная  наудачу  работа  из  работ,  принадлежащих  группе, 
#которая также выбрана наудачу, окажется «отличной».


H1 = "Работы выбрана из группы 1"
H2 = "Работы выбрана из группы 2"
H3 = "Работы выбрана из группы 3"

"Группа выбирается наугад, значит вероятность выбора той или иной группы одинаковая:"
P_H1 = P_H2 = P_H3 = 1/3

"Событие А - выбрана работа, выполненная на отлично"

P_A_H1 = 8/30
P_A_H2 = 6/28
P_A_H3 = 9/27

"По формуле полной вероятности имеем:"
P_A = (P_H1 * P_A_H1) + (P_H2 * P_A_H2) + (P_H3 * P_A_H3)
print ("Вероятность, что наугад выбранная работа из наугад выбранной группы будет отличной: ", P_A)
# Out:
# Вероятность, что наугад выбранная работа из наугад выбранной группы будет отличной:  0.2714285714285714

# %%
#Задание 11

#Турист, заблудившись в лесу, вышел на полянку, от которой в разные стороны 
#ведут 5 дорог. Если турист пойдет по первой дороге, то вероятность выхода туриста из леса в 
#течение часа составляет 0,6; если по второй – 0,3; если по третьей – 0,2; если по четвертой – 0,1; 
#если по пятой – 0,1. Какова вероятность того, что турист 
#пошел по первой дороге, если через час он вышел из леса?


H1 = "Выбрана дорога 1"
H2 = "Выбрана дорога 2"
H3 = "Выбрана дорога 3"
H4 = "Выбрана дорога 4"
H5 = "Выбрана дорога 5"

"Вероятность выбора той или иной дороги одинаковая:"
P_H1 = P_H2 = P_H3 = P_H4 = P_H5 = 1/5


"Событие А - турист вышел из леса за час"
P_A_H1 = 0.6
P_A_H2 = 0.3
P_A_H3 = 0.2
P_A_H4 = 0.1
P_A_H5 = 0.1

"По формуле Байенса имеем:"
P_A = (P_H1*P_A_H1)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2) + (P_H3 * P_A_H3) + (P_H4 * P_A_H4) + (P_H5 * P_A_H5))

print ("Вероятность, что турист пошёл по первой дороге, если вышел из леса за час : ", P_A)
# Out:
# Вероятность, что турист пошёл по первой дороге, если вышел из леса за час :  0.4615384615384615

# %%
#Задание 12


#Среди  поступающих  на  склад  деталей  30%  из  цеха  1,  
#70%  −  из  цеха  2. Вероятность брака для цеха 1 равна 0,02, 
#для цеха 2 – 0,03. Наудачу взятая деталь оказалась доброкачественной.
#Какова вероятность того, что она изготовлена в цехе 1?

H1 = "Выбрана деталь из первого цеха"
H2 = "Выбрана деталь из второго цеха"

"Вероятности выбора детали из первого, второго цеха"
P_H1 = 0.3
P_H2 = 0.7

"Событие А - деталь доброкачественна"
P_A_H1 = 1 - 0.02 
P_A_H2 = 1 - 0.03
print ( P_A_H2)

"По формуле Байенса получаем:"
P_H1_A = (P_H1 * P_A_H1)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2))
print ("Вероятность, что выбранная доброкачественная деталь сделана в 1 цехе : ", P_H1_A)
# Out:
# 0.97
# Вероятность, что выбранная доброкачественная деталь сделана в 1 цехе :  0.302158273381295

# %%
# Задание 13

#Число грузовых машин, проезжающих мимо колонки, относится к числу
##легковых как 3:2. Вероятность того, что грузовая машина будет заправляться, 
#равна 0,1, а того, что будет заправляться легковая 0,2. 
#У бензоколонки заправляется машина. Какова вероятность того, что это грузовая машина?

H1 = "Проехала грузовая машина"
H2 = "Проехала легковая машина"

"Вероятность, что проехала грузовая или легковая машина"
"P_H1/P_H2 = 3/2"
"Всего 5 частей, из них 3 - на грузовые, а 2 на легковые, тогда"
P_H1 = 3/5
P_H2 = 2/5


"Событие А - машина будет заправляться"
P_A_H1 = 0.1 
P_A_H2 = 0.2

"По формуле Байенса получаем:"
P_H1_A = (P_H1 * P_A_H1)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2))
print ("Вероятность, что заправляющаяся машина - грузовая: ", P_H1_A)
# Out:
# Вероятность, что заправляющаяся машина - грузовая:  0.4285714285714285

# %%
#Задание 14

#1/3  ламп  производится  на  первом  заводе,  1/4  –  на  втором,  остальные  –  на 
#третьем. Вероятности брака в продукции первого, второго и третьего заводов 
#соответственно равны  0,2,  0,15  и  0,05.  Найдите  вероятность  того,  
#что  бракованная  лампа  произведена  на первом, втором или третьем заводе. 








H1 = "Лампа произведена на 1-ом заводе"
H2 = "Лампа произведена на 2-ом заводе"
H3 = "Лампа произведена на 3-ем заводе"

"Вероятность того, что лампа сделана на одном из заводов"

P_H1 = 1/3
P_H2 = 1/4
P_H3 = 1 - (1/3+1/4)

"Событие А - деталь бракована"
P_A_H1 = 0.2
P_A_H2 = 0.15
P_A_H3 = 0.05

"По формуле Байенса получаем:"
P_H1_A = (P_H1 * P_A_H1)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2) + (P_H3 * P_A_H3))
print ("Вероятность, что бракованная лампа сделана на первом заводе: ", P_H1_A) 

P_H2_A = (P_H2 * P_A_H2)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2) + (P_H3 * P_A_H3))
print ("Вероятность, что бракованная лампа сделана на втором заводе: ", P_H2_A) 

P_H3_A = (P_H3 * P_A_H3)/((P_H1 * P_A_H1) + (P_H2 * P_A_H2) + (P_H3 * P_A_H3))
print ("Вероятность, что бракованная лампа сделана на третьем заводе: ", P_H3_A)
# Out:
# Вероятность, что бракованная лампа сделана на первом заводе:  0.5333333333333333
# Вероятность, что бракованная лампа сделана на втором заводе:  0.3
# Вероятность, что бракованная лампа сделана на третьем заводе:  0.1666666666666667

# %%
#Задание 15


#В правом и левом карманах имеются по три монетки в 10 коп и по четыре монетки в 5 коп. 
#Из правого кармана в левый наудачу перекладывается 5 монет. 
#Определить вероятность извлечения из левого кармана после перекладывания 
#монеты достоинством в 10 коп.

import math
"Гипотезы о монетах, оставшихся в правом левом карманах после перекладвания"


"""
H1 = 2 монеты по (10 коп.) в правом кармане,
    а в левом - 4 монеты по (10 коп.) и 8 монет по 5 коп. (из правого взяли 1 по 10 коп. и 4 по 5 коп.)

H2 = "По одной монете в (10 и 5 коп) в правом кармане, 
    а в левом - 5 монет по (10 коп) и 7 монет в (5 коп.) (из правого взяли 2 по 10 коп. и 3 по 5 коп.)

H3 = 2 монеты в (5 коп.) в правом кармане,
    а в левом - 6 монет по (10 коп.) и 6 монет по (5 коп.) (из правого взяли 3 по 10 коп. и 2 по 5 коп.)
"""

"Для подсчёта вероятностей необходимо посчитать количество благоприятных и всех исходов, для этого посчитаем сочетания"
"В каждом кармане по 7 монет, а выбирают 5. Тогда общее число исходов:"
C_H = math.comb(7, 5)

#P_H1
C_1_10к = math.comb(3, 1)
C_4_5к = math.comb(4, 4)

P_H1 = (C_1_10к * C_4_5к)/C_H
print("Вероятность H1: ", P_H1)


#P_H2
C_2_10к = math.comb(3, 2)
C_3_5к = math.comb(4, 3)

P_H2 = (C_2_10к * C_3_5к)/C_H
print("Вероятность H2: ", P_H2)


#P_H3
C_3_10к = math.comb(3, 3)
C_2_5к = math.comb(4, 2)

P_H3 = (C_3_10к * C_2_5к)/C_H
print("Вероятность H3: ", P_H3)


"Условные вероятности"
"После перекладывания в левом кармане стало 12 монет, тогда:"
P_A_H1 = 4/12
P_A_H2 = 5/12
P_A_H3 = 6/12

"По формуле полной вероятности получаем:"
P_A = P_H1 * P_A_H1 + P_H2 * P_A_H2 + P_H3 * P_A_H3
print("Вероятность, что из левого кармана достант монету в 10 коп. равна: ", P_A)
# Out:
# Вероятность H1:  0.14285714285714285
# Вероятность H2:  0.5714285714285714
# Вероятность H3:  0.2857142857142857
# Вероятность, что из левого кармана достант монету в 10 коп. равна:  0.42857142857142855
